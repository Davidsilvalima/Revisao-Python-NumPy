# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

array = np.random.normal(10, 0.5, size=50)
print(array)
sns.histplot(array)
# Out:
# [ 9.94312762  9.38317165 10.26917182  9.49569488 10.21571494 10.29744899
#  10.16773031  9.94384318  9.36337892  9.85767032 10.52514509 10.36466889
#  10.59704493  9.78947692 10.26769219 10.67663939  9.60636299 10.05413175
#   9.38809828 10.32837517  9.46394003  9.66871271 10.80184119  9.63586792
#  10.00384679  9.07467677  9.25163844  9.3992324   9.99262312 10.38997957
#   9.96424803  9.6283104  10.45874144  9.99472568  9.89665588 10.35456024
#   9.57773673  9.30257035  9.62397407 10.70820954  9.3275119  10.06587308
#  11.51405172  9.3959419   9.79838716  9.30383702 10.66725691 10.33212114
#  10.61652603 10.32311265]
# <AxesSubplot:ylabel='Count'>

# %%
sns.kdeplot(array)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.boxplot(data = array)
# Out:
# <AxesSubplot:>

# %%
 sns.violinplot(data = array)
# Out:
# <AxesSubplot:>

# %%
A = np.array([[1, 2], [3, 4]])
B = np.array([[1, 1], [1, 0]])

# %%
A
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
B
# Out:
# array([[1, 1],
#        [1, 0]])

# %%
A+B
# Out:
# array([[2, 3],
#        [4, 4]])

# %%
A.trace()
# Out:
# 5

# %%
B.trace()
# Out:
# 1

# %%
np.dot(A, B)
# Out:
# array([[3, 1],
#        [7, 3]])

# %%
A = np.array([[1, 2], [3, 4]])
B = np.array([[1, 1], [1, 0]])

import numpy as np

np.linalg.det(A)
# Out:
# -2.0000000000000004

# %%
A = np.array([[1, 2], [3, 4]])
B = np.array([[1, 1], [1, 0]])
np.linalg.det(B)
# Out:
# -1.0

# %%
np.linalg.inv(A)
# Out:
# array([[-2. ,  1. ],
#        [ 1.5, -0.5]])

# %%
np.linalg.inv(B)
# Out:
# array([[ 0.,  1.],
#        [ 1., -1.]])
